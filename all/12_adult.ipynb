# %%
import pandas as pd

# %%
df=pd.read_csv("E:/PICT 3rd/subject material/DSBDA Prep/Datasets/archive2/adult.csv")

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
country_df=df[df["native.country"]=="United-States"]
sex_df=df[df["sex"]=="Male"]
race_df=df[df["race"]=="White"]

# %%
merg_df=pd.concat([country_df,sex_df])

# %%
merg_df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32554   32   Private  116138       Masters             14       Never-married
# 32555   53   Private  321865       Masters             14  Married-civ-spouse
# 32556   22   Private  310152  Some-college             10       Never-married
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
sorted_df=df.sort_values("hours.per.week",ascending=False)

# %%
sorted_df.head()
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 20662   43           Private  249771       HS-grad              9
# 730     43           Private  266324       HS-grad              9
# 28699   61                 ?  158712       HS-grad              9
# 15198   51           Private  160724     Doctorate             16
# 5853    55  Self-emp-not-inc  184425  Some-college             10
#
#            marital.status        occupation   relationship  \
# 20662  Married-civ-spouse  Transport-moving        Husband
# 730    Married-civ-spouse      Craft-repair        Husband
# 28699            Divorced                 ?  Not-in-family
# 15198  Married-civ-spouse    Prof-specialty        Husband
# 5853   Married-civ-spouse   Farming-fishing        Husband
#
#                      race     sex  capital.gain  capital.loss  hours.per.week  \
# 20662  Asian-Pac-Islander    Male             0             0              99
# ...

# %%
transposed=df.head(5).transpose()

# %%
transposed
# Out:
#                             0                1              2  \
# age                        90               82             66
# workclass                   ?          Private              ?
# fnlwgt                  77053           132870         186061
# education             HS-grad          HS-grad   Some-college
# education.num               9                9             10
# marital.status        Widowed          Widowed        Widowed
# occupation                  ?  Exec-managerial              ?
# relationship    Not-in-family    Not-in-family      Unmarried
# race                    White            White          Black
# sex                    Female           Female         Female
# capital.gain                0                0              0
# capital.loss             4356             4356           4356
# hours.per.week             40               18             40
# native.country  United-States    United-States  United-States
# ...

# %%
melted=pd.melt(df,id_vars=['age','sex'],value_vars=['education','race'], var_name='Feature',value_name="Value")

# %%
melted.head()
# Out:
#    age     sex    Feature         Value
# 0   90  Female  education       HS-grad
# 1   82  Female  education       HS-grad
# 2   66  Female  education  Some-college
# 3   54  Female  education       7th-8th
# 4   41  Female  education  Some-college

# %%
pivoted=melted.pivot_table(index='age',columns="Feature",values="Value",aggfunc="first")

# %%
pivoted
# Out:
# Feature     education   race
# age
# 17               11th  White
# 18            HS-grad  White
# 19               11th  White
# 20       Some-college  White
# 21          Assoc-voc  White
# ..                ...    ...
# 85            HS-grad  White
# 86            Masters  White
# 87            HS-grad  White
# 88        Prof-school  White
# 90            HS-grad  White
#
# [73 rows x 2 columns]
