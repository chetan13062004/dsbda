# %%
import pandas as pd

# %%
df=pd.read_csv("E:/PICT 3rd/subject material/DSBDA Prep/Datasets/archive/Dataset_Facebook.csv",sep=";");

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
photo_post=df[df["Type"]=="Photo"]
status_post=df[df["Type"]=="Status"]

# %%
merged_posts=pd.concat([photo_post,status_post])

# %%
sorted_df=df.sort_values("Page total likes",ascending=False)

# %%
transposed=df.head(3).transpose()

# %%
melted = pd.melt(df, id_vars=['Post Month', 'Post Weekday'], value_vars=['Type', 'Category'])

# %%
melted
# Out:
#      Post Month  Post Weekday  variable   value
# 0            12             4      Type   Photo
# 1            12             3      Type  Status
# 2            12             3      Type   Photo
# 3            12             2      Type   Photo
# 4            12             2      Type   Photo
# ..          ...           ...       ...     ...
# 995           1             7  Category       3
# 996           1             5  Category       2
# 997           1             5  Category       1
# 998           1             4  Category       3
# 999           1             4  Category       2
#
# [1000 rows x 4 columns]

# %%
pivoted = melted.pivot_table(
    index=['Post Month', 'Post Weekday'],
    columns='variable',
    values='value',
    aggfunc='first'  # or 'sum', 'max', 'min' depending on use-case
)

print(pivoted.head())
# Out:
# variable                Category   Type
# Post Month Post Weekday
# 1          1                   3  Photo
#            2                   3  Photo
#            3                   3  Photo
#            4                   2  Photo
#            5                   3  Photo

# %%
print("Subset - Photo Posts:\n", photo_post.head(), "\n")
print("Merged Posts:\n", merged_posts.head(), "\n")
print("Sorted by Likes:\n", sorted_df[['Type', 'Page total likes']].head(), "\n")
print("Transposed:\n", transposed, "\n")
print("Melted Data:\n", meltdf.head(), "\n")
# Out:
# Subset - Photo Posts:
#     Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...
